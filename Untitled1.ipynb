# %% [markdown]
# ## Machine larning with python: linear Regression with one variable

# %% [markdown]
# #### Sample Problem of predicting home prices and

# %%
import pandas as pd

# %%
df=pd.read_csv("homeprices (2).csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [raw]
# ### Problem Statement:

# %% [markdown]
# ### Given above data build a machine learning model that can predict home prices based on square feet area

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area,df.price,color="red")

# %%
df.price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
type(df.price)
# Out:
# pandas.core.series.Series

# %%
type(df.area)
# Out:
# pandas.core.series.Series

# %%
df[["area"]]
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
type(df[["area"]])
# Out:
# pandas.core.frame.DataFrame

# %%
#y=mx+c
#y=(prediction value or target or dependent variable) for ex: price
#m= Slape
#x=(independent variable) for ex: area
#c=y-intercept

# %%
price=df.price

# %%
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
x=df.drop("price",axis="columns")

# %%
x
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
# !pip install sci-kit learn

# %% [markdown]
# ## Sci-Kit Learn

# %% [markdown]
# ## Science kit for the purpose of machine learning Algorithums
# #### - feature Engineering
# #### - data preprocessing
# #### - Model slection
# #### - USED for the purpose of model development intems of supervised,unsupervised Learnings

# %%
from sklearn import linear_model

# %%
## Linear model =Linear Regression / Logistic Regression etc

# %% [markdown]
# ###www.mathisfun.com/algebra/linear-equations.html

# %%
# creating linear model object

reg = linear_model.LinearRegression()

# %%
reg.fit(x,price)
# Out:
# LinearRegression()

# %%
reg.predict([[10000]])
# Out:
# C:\Users\YouExcel\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1538493.15068493])

# %%
import pickle

# %%
pickle.dump(reg, open("area.pkl","wb"))  #wb = write binary
